# %% [markdown]
# # Quadratic Series Forecast (Quadratic Regression)

# %%
import matplotlib.pyplot as plt

from mintalib.samples import sample_prices
from mintalib.indicators import HMA, TSF, QSF, DEMA, TEMA

plt.rc("figure", figsize=(12, 9))

# %%
PERIOD = 50

prices = sample_prices()

prices = prices.assign(
    tsf=TSF(PERIOD),
    qsf=QSF(PERIOD),
    hma=HMA(PERIOD),
    dema=DEMA(PERIOD),
    tema=TEMA(PERIOD)
)

prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11056 entries, 1980-12-12 to 2024-10-21
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    11056 non-null  float64
#  1   high    11056 non-null  float64
#  2   low     11056 non-null  float64
#  3   close   11056 non-null  float64
#  4   volume  11056 non-null  int64
#  5   tsf     11007 non-null  float64
#  6   qsf     11007 non-null  float64
#  7   hma     11001 non-null  float64
#  8   dema    10958 non-null  float64
#  9   tema    10909 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 950.1 KB

# %%
prices.tail(250).plot(
    y=["close", "qsf", "tsf"],
    title="QSF vs TSF",
    use_index=False,
);

# %%
prices.tail(250).plot(
    y=["close", "qsf", "hma"],
    title="QSF vs HMA",
    use_index=False
);

# %%
prices.tail(250).plot(
    y=["close", "qsf", "dema"],
    title="QSF vs DEMA",
    use_index=False,
);

# %%
prices.tail(250).plot(
    y=["close", "qsf", "tema"],
    title="QSF vs TEMA",
    use_index=False,
);
