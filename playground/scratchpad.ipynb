# %%
import mintalib.functions as ta
import mintalib.expressions as exp
import mintalib.indicators as ind


from mintalib.samples import sample_prices

# %%
prices = sample_prices(backend="pandas")
plprices = sample_prices(backend="polars")

# %%
ta.obv(prices.close, prices.volume)
# Out:
# date
# 1980-12-12    4.690336e+08
# 1980-12-15    2.931488e+08
# 1980-12-16    1.874208e+08
# 1980-12-17    2.738624e+08
# 1980-12-18    3.473120e+08
#                   ...
# 2026-07-31    1.651209e+11
# 2026-08-03    1.650458e+11
# 2026-08-04    1.651138e+11
# 2026-08-05    1.651630e+11
# 2026-08-06    1.651702e+11
# Length: 11504, dtype: float64
