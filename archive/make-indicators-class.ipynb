# %% [markdown]
# # Notebook to generate indicators module

# %%
from pprint import pformat

from inspect import Signature, Parameter

from mintalib import core
from mintalib.samples import sample_prices

from __project__ import PKGDIR

# %%
prices = sample_prices()
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11033 entries, 1980-12-12 to 2024-09-18
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    11033 non-null  float64
#  1   high    11033 non-null  float64
#  2   low     11033 non-null  float64
#  3   close   11033 non-null  float64
#  4   volume  11033 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 517.2 KB

# %%
import importlib.util

def new_module(name: str, code: str = None):
    spec = importlib.util.spec_from_loader(name, None)
    module = importlib.util.module_from_spec(spec)
    if code:
        exec(code, module.__dict__)
    return module

# %%
def core_functions():
    return tuple(k for k, v in vars(core).items() if k.isupper() and callable(v))

core_functions()
# Out:
# ('AVGPRICE',
#  'TYPPRICE',
#  'WCLPRICE',
#  'MIDPRICE',
#  'PRICE',
#  'CROSSOVER',
#  'CROSSUNDER',
#  'FLAG_ABOVE',
#  'FLAG_BELOW',
#  'FLAG_INVERT',
#  'FLAG_UPDOWN',
#  'LOG',
#  'EXP',
#  'ROC',
#  'DIFF',
#  'MIN',
#  'MAX',
#  'SUM',
#  'MAD',
#  'STDEV',
#  'SMA',
#  'EMA',
#  'RMA',
#  'WMA',
#  'HMA',
#  'DEMA',
#  'TEMA',
#  'MA',
#  'RSI',
#  'PLUSDI',
#  'MINUSDI',
#  'ADX',
#  'TRANGE',
#  'ATR',
#  'NATR',
#  'LATR',
#  'SAR',
#  'CCI',
#  'CMF',
#  'MFI',
#  'BOP',
#  'BBANDS',
#  'KELTNER',
#  'KER',
#  'KAMA',
#  'MACD',
#  'PPO',
#  'SLOPE',
#  'RVALUE',
#  'FORECAST',
#  'STOCH',
#  'STREAK',
#  'EVAL')

# %%
# Sample code for indicator

from mintalib.model import Indicator
from mintalib.core import wrap_indicator

@wrap_indicator(core.EMA)
class EMA(Indicator):
    same_scale = True

    def __init__(self, period: int, *, item: str = None):
        self.period = period
        self.item = item

    def __call__(self, series):
        return core.EMA(series, period=self.period)

# %%
PREAMBLE = '''
""" Mintalib Indicators """

# Do not edit! This file was generated by make-indicators.ipynb

from . import core
from . import model

nan = float('nan')

'''


def make_indicator(func, name: str = None, preamble=False, verbose=False):
    if name is None:
        name = func.__name__.upper()

    fname = func.__qualname__
    module = func.__module__.rpartition(".")[2]
    qname = f"{module}.{fname}"

    indent = " " * 4
    indent2 = " " * 8

    signature = Signature.from_callable(func)
    parameters = list(signature.parameters.values())

    if verbose:
        print("signature", signature)
        print("parameters", parameters)

    newparams = []
    ftype = parameters[0].name

    def annotate(param):
        if param.name in ["period"]:
            return param.replace(annotation=int)

        if param.annotation == "str":
            return param.replace(annotation=str)

        if type(p.default) in (int, float, bool):
            return param.replace(annotation=type(p.default))

        return param

    for i, p in enumerate(parameters):
        if i == 0:
            p = Parameter("self", Parameter.POSITIONAL_OR_KEYWORD)
        else:
            p = annotate(p)
        newparams.append(p)

    if verbose:
        print("newparams", newparams)

    newsig = Signature(newparams)

    def argument(arg):
        return ftype if arg == "self" else f"{arg}=self.{arg}"

    args = [argument(p.name) for p in newparams]
    args = ", ".join(args)

    code = PREAMBLE if preamble else ""
    # code = "# noinspection PyPep8Naming\n"

    code += f"@core.wrap_function({qname})\n"
    code += f"class {name}(model.Indicator):\n"

    if len(newparams) > 1:
        code += indent + f"def __init__{newsig}:\n"
        for p in newparams[1:]:
            name = p.name
            code += indent2 + f"self.{name} = {name}\n"
        code += "\n"

    code += indent + f"def __call__(self, {ftype}):\n"
    code += indent2 + f"return {qname}({args})\n"

    return code


print(make_indicator(core.EMA))
# Out:
# @core.wrap_function(core.EMA)
# class EMA(model.Indicator):
#     def __init__(self, period: int, *, adjust: bool = False, item: str = None):
#         self.period = period
#         self.adjust = adjust
#         self.item = item
#
#     def __call__(self, series):
#         return core.EMA(series, period=self.period, adjust=self.adjust, item=self.item)

# %%
def test_indicator(func, name=None, verbose=False):
    code = make_indicator(func, name=name, preamble=True, verbose=verbose)
    print(code)
    return new_module("mintalib.functions", code)


test_indicator(core.EMA)
# Out:
# """ Mintalib Indicators """
#
# # Do not edit! This file was generated by make-indicators.ipynb
#
# from . import core
# from . import model
#
# nan = float('nan')
#
# @core.wrap_function(core.EMA)
# class EMA(model.Indicator):
#     def __init__(self, period: int, *, adjust: bool = False, item: str = None):
#         self.period = period
#         self.adjust = adjust
#         self.item = item
#
#     def __call__(self, series):
#         return core.EMA(series, period=self.period, adjust=self.adjust, item=self.item)
# <module 'mintalib.functions'>

# %%
def make_indicators(names=None):
    if names is None:
        names = core_functions()

    output = PREAMBLE

    buffer = pformat(names, width=75, compact=True, indent=4)
    buffer = buffer.replace("(", " ").replace(")", "")
    output += f"__all__ = [\n{buffer}\n]\n"

    output += "\n\n"

    for name in names:
        func = getattr(core, name)
        text = make_indicator(func)
        output += text + "\n\n"


    return output


code = make_indicators()
print(code[:256], "...")
# Out:
# """ Mintalib Indicators """
#
# # Do not edit! This file was generated by make-indicators.ipynb
#
# from . import core
# from . import model
#
# nan = float('nan')
#
# __all__ = [
#     'AVGPRICE', 'TYPPRICE', 'WCLPRICE', 'MIDPRICE', 'PRICE', 'CROSSOVER',
#     'CROSSUNDER ...

# %%
code = make_indicators()

indicators = new_module("mintalib.indicators", code)

dir(indicators)
# Out:
# ['ADX',
#  'ATR',
#  'AVGPRICE',
#  'BBANDS',
#  'BOP',
#  'CCI',
#  'CMF',
#  'CROSSOVER',
#  'CROSSUNDER',
#  'DEMA',
#  'DIFF',
#  'EMA',
#  'EVAL',
#  'EXP',
#  'FLAG_ABOVE',
#  'FLAG_BELOW',
#  'FLAG_INVERT',
#  'FLAG_UPDOWN',
#  'FORECAST',
#  'HMA',
#  'KAMA',
#  'KELTNER',
#  'KER',
#  'LATR',
#  'LOG',
#  'MA',
#  'MACD',
#  'MAD',
#  'MAX',
#  'MFI',
#  'MIDPRICE',
#  'MIN',
#  'MINUSDI',
#  'NATR',
#  'PLUSDI',
#  'PPO',
#  'PRICE',
#  'RMA',
#  'ROC',
#  'RSI',
#  'RVALUE',
#  'SAR',
#  'SLOPE',
#  'SMA',
#  'STDEV',
#  'STOCH',
#  'STREAK',
#  'SUM',
#  'TEMA',
#  'TRANGE',
#  'TYPPRICE',
#  'WCLPRICE',
#  'WMA',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'core',
#  'model',
#  'nan']

# %%
assert callable(indicators.SMA)
assert callable(indicators.SMA(20))

res = indicators.SMA(20) @ prices

assert len(res) > 0

# %%
outfile = PKGDIR / "indicators.py"

print(f"Updating {outfile.name} ...")

outfile.write_text(code)
# Out:
# Updating indicators.py ...
# 14703

# %%
from mintalib import indicators

# %%
help(indicators)
# Out:
# Help on module mintalib.indicators in mintalib:
#
# NAME
#     mintalib.indicators - Mintalib Indicators
#
# CLASSES
#     mintalib.model.Indicator(builtins.object)
#         ADX
#         ATR
#         AVGPRICE
#         BBANDS
#         BOP
#         CCI
#         CMF
#         CROSSOVER
#         CROSSUNDER
#         DEMA
#         DIFF
#         EMA
#         EVAL
#         EXP
#         FLAG_ABOVE
#         FLAG_BELOW
#         FLAG_INVERT
#         FLAG_UPDOWN
#         FORECAST
#         HMA
#         KAMA
#         KELTNER
#         KER
#         LATR
#         LOG
#         MA
#         MACD
#         MAD
#         MAX
#         MFI
#         MIDPRICE
#         MIN
#         MINUSDI
#         NATR
#         PLUSDI
#         PPO
#         PRICE
#         RMA
#         ROC
#         RSI
#         RVALUE
#         SAR
#         SLOPE
#         SMA
#         STDEV
#         STOCH
#         STREAK
#         SUM
#         TEMA
#         TRANGE
#         TYPPRICE
#         WCLPRICE
#         WMA
#
#     class ADX(mintalib.model.Indicator)
#      |  ADX(period: int = 14)
#      |
#      |  Average Directional Index
#      |
#      |  Method resolution order:
#      |      ADX
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 14)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class ATR(mintalib.model.Indicator)
#      |  ATR(period: int = 14)
#      |
#      |  Average True Range
#      |
#      |  Method resolution order:
#      |      ATR
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 14)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class AVGPRICE(mintalib.model.Indicator)
#      |  Average Price
#      |
#      |  Method resolution order:
#      |      AVGPRICE
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class BBANDS(mintalib.model.Indicator)
#      |  BBANDS(period: int = 20, nbdev: float = 2.0)
#      |
#      |  Bollinger Bands
#      |
#      |  Method resolution order:
#      |      BBANDS
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20, nbdev: float = 2.0)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class BOP(mintalib.model.Indicator)
#      |  BOP(period: int = 20)
#      |
#      |  Balance of Power
#      |
#      |  Method resolution order:
#      |      BOP
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class CCI(mintalib.model.Indicator)
#      |  CCI(period: int = 20)
#      |
#      |  Commodity Channel Index
#      |
#      |  Method resolution order:
#      |      CCI
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class CMF(mintalib.model.Indicator)
#      |  CMF(period: int = 20)
#      |
#      |  Chaikin Money Flow
#      |
#      |  Method resolution order:
#      |      CMF
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class CROSSOVER(mintalib.model.Indicator)
#      |  CROSSOVER(level: float = 0.0, *, item: str = None)
#      |
#      |  Cross Over
#      |
#      |  Method resolution order:
#      |      CROSSOVER
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, level: float = 0.0, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class CROSSUNDER(mintalib.model.Indicator)
#      |  CROSSUNDER(level: float = 0.0, *, item: str = None)
#      |
#      |  Cross Under
#      |
#      |  Method resolution order:
#      |      CROSSUNDER
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, level: float = 0.0, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class DEMA(mintalib.model.Indicator)
#      |  DEMA(period: int, *, item: str = None)
#      |
#      |  Double Exponential Moving Average
#      |
#      |  Method resolution order:
#      |      DEMA
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class DIFF(mintalib.model.Indicator)
#      |  DIFF(period: int = 1, *, item: str = None)
#      |
#      |  Difference
#      |
#      |  Method resolution order:
#      |      DIFF
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 1, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class EMA(mintalib.model.Indicator)
#      |  EMA(period: int, *, adjust: bool = False, item: str = None)
#      |
#      |  Exponential Moving Average
#      |
#      |  Args:
#      |      period (int) : time period, required
#      |      adjust (bool) : whether to adjust weights, default False
#      |          when true update ratio increases gradually (see formula)
#      |
#      |  Formula:
#      |      EMA is calculated as a recursive formula
#      |      The standard formula is ema += alpha * (value - ema)
#      |          with alpha = 2.0 / (period + 1.0)
#      |      The adjusted formula is ema = num/div
#      |          where num = value + rho * num, div = 1.0 + rho * div
#      |          with rho = 1.0 - alpha
#      |
#      |  Method resolution order:
#      |      EMA
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int, *, adjust: bool = False, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class EVAL(mintalib.model.Indicator)
#      |  EVAL(expr: str)
#      |
#      |  Expression Eval (pandas only)
#      |
#      |  Method resolution order:
#      |      EVAL
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, expr: str)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class EXP(mintalib.model.Indicator)
#      |  EXP(*, item: str = None)
#      |
#      |  Exponential
#      |
#      |  Method resolution order:
#      |      EXP
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class FLAG_ABOVE(mintalib.model.Indicator)
#      |  FLAG_ABOVE(level: float = 0.0, *, item: str = None)
#      |
#      |  Flag for value above level
#      |
#      |  Method resolution order:
#      |      FLAG_ABOVE
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, level: float = 0.0, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class FLAG_BELOW(mintalib.model.Indicator)
#      |  FLAG_BELOW(level: float = 0.0, *, item: str = None)
#      |
#      |  Flag for value below level
#      |
#      |  Method resolution order:
#      |      FLAG_BELOW
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, level: float = 0.0, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class FLAG_INVERT(mintalib.model.Indicator)
#      |  FLAG_INVERT(*, item: str = None)
#      |
#      |  Inverse flag
#      |
#      |  Method resolution order:
#      |      FLAG_INVERT
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class FLAG_UPDOWN(mintalib.model.Indicator)
#      |  FLAG_UPDOWN(up_level: float = 0.0, down_level: float = 0.0, *, item: str = None)
#      |
#      |  Flag for value crossing up & down levels
#      |
#      |  Method resolution order:
#      |      FLAG_UPDOWN
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, up_level: float = 0.0, down_level: float = 0.0, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class FORECAST(mintalib.model.Indicator)
#      |  FORECAST(period: int = 20, offset: int = 0, *, item: str = None)
#      |
#      |  Forecast (time linear regression)
#      |
#      |  Method resolution order:
#      |      FORECAST
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20, offset: int = 0, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class HMA(mintalib.model.Indicator)
#      |  HMA(period: int, *, item: str = None)
#      |
#      |  Hull Moving Average
#      |
#      |  Method resolution order:
#      |      HMA
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class KAMA(mintalib.model.Indicator)
#      |  KAMA(period: int = 10, fastn: int = 2, slown: int = 30, *, item: str = None)
#      |
#      |  Kaufman Adaptive Moving Average
#      |
#      |  Method resolution order:
#      |      KAMA
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 10, fastn: int = 2, slown: int = 30, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class KELTNER(mintalib.model.Indicator)
#      |  KELTNER(period: int = 20, nbatr: float = 2.0)
#      |
#      |  Keltner Channel
#      |
#      |  Method resolution order:
#      |      KELTNER
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20, nbatr: float = 2.0)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class KER(mintalib.model.Indicator)
#      |  KER(period: int = 10, *, item: str = None)
#      |
#      |  Kaufman Efficiency Ratio
#      |
#      |  Method resolution order:
#      |      KER
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 10, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class LATR(mintalib.model.Indicator)
#      |  LATR(period: int = 14)
#      |
#      |  Average True Range (logarithmic)
#      |
#      |  Method resolution order:
#      |      LATR
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 14)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class LOG(mintalib.model.Indicator)
#      |  LOG(*, item: str = None)
#      |
#      |  Logarithm
#      |
#      |  Method resolution order:
#      |      LOG
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class MA(mintalib.model.Indicator)
#      |  MA(period: int = 20, *, ma_type: str = None, item: str = None)
#      |
#      |  Generic Moving Average
#      |
#      |  Args:
#      |      matype (str) : one of 'SMA', 'EMA', 'WMA', 'HMA', 'DEMA', 'TEMA'
#      |              defaults to 'SMA'
#      |
#      |  Method resolution order:
#      |      MA
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20, *, ma_type: str = None, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class MACD(mintalib.model.Indicator)
#      |  MACD(n1: int = 12, n2: int = 26, n3: int = 9, *, item: str = None)
#      |
#      |  Moving Average Convergenge Divergence
#      |
#      |  Method resolution order:
#      |      MACD
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, n1: int = 12, n2: int = 26, n3: int = 9, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class MAD(mintalib.model.Indicator)
#      |  MAD(period: int = 20, *, item: str = None)
#      |
#      |  Mean Absolute Deviation
#      |
#      |  Method resolution order:
#      |      MAD
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class MAX(mintalib.model.Indicator)
#      |  MAX(period: int, *, item: str = None)
#      |
#      |  Rolling Maximum
#      |
#      |  Method resolution order:
#      |      MAX
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class MFI(mintalib.model.Indicator)
#      |  MFI(period: int = 14)
#      |
#      |  Money Flow Index
#      |
#      |  Method resolution order:
#      |      MFI
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 14)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class MIDPRICE(mintalib.model.Indicator)
#      |  Mid Price
#      |
#      |  Method resolution order:
#      |      MIDPRICE
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
# ...
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class SMA(mintalib.model.Indicator)
#      |  SMA(period: int, *, item: str = None)
#      |
#      |  Simple Moving Average
#      |
#      |  Method resolution order:
#      |      SMA
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class STDEV(mintalib.model.Indicator)
#      |  STDEV(period: int = 20, *, item: str = None)
#      |
#      |  Standard Deviation
#      |
#      |  Method resolution order:
#      |      STDEV
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class STOCH(mintalib.model.Indicator)
#      |  STOCH(period: int = 14, fastn: int = 3, slown: int = 3)
#      |
#      |  Stochastic Oscillator
#      |
#      |  Method resolution order:
#      |      STOCH
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 14, fastn: int = 3, slown: int = 3)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class STREAK(mintalib.model.Indicator)
#      |  STREAK(*, item: str = None)
#      |
#      |  Consecutive streak of ups or downs
#      |
#      |  Method resolution order:
#      |      STREAK
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class SUM(mintalib.model.Indicator)
#      |  SUM(period: int, *, item: str = None)
#      |
#      |  Rolling Sum
#      |
#      |  Method resolution order:
#      |      SUM
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class TEMA(mintalib.model.Indicator)
#      |  TEMA(period: int = 20, *, item: str = None)
#      |
#      |  Triple Exponential Moving Average
#      |
#      |  Method resolution order:
#      |      TEMA
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int = 20, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class TRANGE(mintalib.model.Indicator)
#      |  TRANGE(*, log_prices: bool = False, percent: bool = False)
#      |
#      |  True Range
#      |
#      |  Method resolution order:
#      |      TRANGE
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  __init__(self, *, log_prices: bool = False, percent: bool = False)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class TYPPRICE(mintalib.model.Indicator)
#      |  Typical Price
#      |
#      |  Method resolution order:
#      |      TYPPRICE
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class WCLPRICE(mintalib.model.Indicator)
#      |  Weighted Close Price
#      |
#      |  Method resolution order:
#      |      WCLPRICE
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, prices)
#      |      Call self as a function.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
#     class WMA(mintalib.model.Indicator)
#      |  WMA(period: int, *, item: str = None)
#      |
#      |  Weighted Moving Average
#      |
#      |  Method resolution order:
#      |      WMA
#      |      mintalib.model.Indicator
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, series)
#      |      Call self as a function.
#      |
#      |  __init__(self, period: int, *, item: str = None)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __matmul__(self, other)
#      |
#      |  __repr__ = lazy_repr(obj)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  __annotations__ = {'same_scale': <class 'bool'>}
#      |
#      |  same_scale = False
#
# DATA
#     __all__ = ['AVGPRICE', 'TYPPRICE', 'WCLPRICE', 'MIDPRICE', 'PRICE', 'C...
#
# FILE
#     /Users/frederic/Projects/mintalib/src/mintalib/indicators.py
