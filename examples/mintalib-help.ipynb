# %% [markdown]
# # Examples on getting help with mintalib

# %%
from mintalib import functions
from mintalib import indicators

# %%
print(functions.__all__)
# Out:
# ['ADX', 'ATR', 'AVGPRICE', 'BBANDS', 'BOP', 'CCI', 'CMF', 'CURVE', 'DEMA', 'DIFF', 'EMA', 'EXP', 'KAMA', 'KELTNER', 'LATR', 'LOG', 'MA', 'MACD', 'MAD', 'MAX', 'MFI', 'MIDPRICE', 'MIN', 'MINUSDI', 'NATR', 'PLUSDI', 'PPO', 'PSAR', 'ROC', 'RSI', 'SLOPE', 'SMA', 'STDEV', 'STOCH', 'STREAK', 'SUM', 'TEMA', 'TRANGE', 'TYPPRICE', 'WCLPRICE', 'WMA']

# %%
print(indicators.__all__)
# Out:
# ['ADX', 'ATR', 'AVGPRICE', 'BBANDS', 'BOP', 'CCI', 'CMF', 'CURVE', 'DEMA', 'DIFF', 'EMA', 'EVAL', 'EXP', 'KAMA', 'KELTNER', 'LATR', 'LOG', 'MACD', 'MAD', 'MAX', 'MFI', 'MIDPRICE', 'MIN', 'MINUSDI', 'NATR', 'PLUSDI', 'PPO', 'PRICE', 'PSAR', 'RMA', 'ROC', 'RSI', 'SLOPE', 'SMA', 'STDEV', 'STOCH', 'SUM', 'TEMA', 'TRANGE', 'TYPPRICE', 'VOLUME', 'WCLPRICE', 'WMA']

# %%
help(functions.EMA)
# Out:
# Help on function EMA in module mintalib.functions:
#
# EMA(series, period: int, *, adjust: bool = False, item: str = None)
#     Exponential Moving Average
#
#     Args:
#         series (series) : data series, required
#         period (int) : time period, required
#         adjust (bool) : whether to adjust weights, default False
#             when true update ratio increases gradually (see formula)
#
#     Formula:
#         EMA is calculated as a recursive formula
#         The standard formula is ema += alpha * (value - ema)
#             with alpha = 2.0 / (period + 1.0)
#         The adjusted formula is ema = num/div
#             where num = value + rho * num, div = 1.0 + rho * div
#             with rho = 1.0 - alpha

# %%
help(indicators.EMA)
# Out:
# Help on class EMA in module mintalib.core:
#
# class EMA(mintalib.model.Indicator)
#  |  EMA(period: 'int', *, item=None)
#  |
#  |  Exponential Moving Average
#  |
#  |  Args:
#  |      period (int) : time period, required
#  |      adjust (bool) : whether to adjust weights, default False
#  |          when true update ratio increases gradually (see formula)
#  |
#  |  Formula:
#  |      EMA is calculated as a recursive formula
#  |      The standard formula is ema += alpha * (value - ema)
#  |          with alpha = 2.0 / (period + 1.0)
#  |      The adjusted formula is ema = num/div
#  |          where num = value + rho * num, div = 1.0 + rho * div
#  |          with rho = 1.0 - alpha
#  |
#  |  Method resolution order:
#  |      EMA
#  |      mintalib.model.Indicator
#  |      abc.ABC
#  |      mintalib.model.ReprMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, period: 'int', *, item=None)
#  |
#  |  calc(self, data)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  same_scale = True
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from mintalib.model.Indicator:
#  |
#  |  __call__(self, data)
#  |      Call self as a function.
#  |
#  |  __matmul__(self, other)
#  |
#  |  clone(self, **kwargs)
#  |
#  |  get_series(self, data)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from mintalib.model.Indicator:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from mintalib.model.Indicator:
#  |
#  |  default_item = 'close'
#  |
#  |  item = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from mintalib.model.ReprMixin:
#  |
#  |  __repr__(self)
#  |      Return repr(self).

# %%
help(functions)
# Out:
# Help on module mintalib.functions in mintalib:
#
# NAME
#     mintalib.functions - Create a module object.
#
# DESCRIPTION
#     The name must be a string; the optional doc argument can have any type.
#
# FUNCTIONS
#     ADX(prices, period: int = 14)
#         Average Directional Index
#
#     ATR(prices, period: int = 14)
#         Average True Range
#
#     AVGPRICE(prices)
#         Average Price
#
#     BBANDS(prices, period: int = 20, nbdev: float = 2.0)
#         Bollinger Bands
#
#     BOP(prices, period: int = 20)
#         Balance of Power
#
#     CCI(prices, period: int = 20)
#         Commodity Channel Index
#
#     CMF(prices, period: int = 20)
#         Chaikin Money Flow
#
#     CURVE(series, period: int = 20, *, option: int = 0, offset: int = 0, item: str = None)
#         Curve (time curvilinear regression)
#
#     DEMA(series, period: int, *, item: str = None)
#         Double Exponential Moving Average
#
#     DIFF(series, period: int = 1, *, item: str = None)
#         Difference
#
#     EMA(series, period: int, *, adjust: bool = False, item: str = None)
#         Exponential Moving Average
#
#         Args:
#             series (series) : data series, required
#             period (int) : time period, required
#             adjust (bool) : whether to adjust weights, default False
#                 when true update ratio increases gradually (see formula)
#
#         Formula:
#             EMA is calculated as a recursive formula
#             The standard formula is ema += alpha * (value - ema)
#                 with alpha = 2.0 / (period + 1.0)
#             The adjusted formula is ema = num/div
#                 where num = value + rho * num, div = 1.0 + rho * div
#                 with rho = 1.0 - alpha
#
#     EXP(series, *, item: str = None)
#         Exponential
#
#     KAMA(series, period: int = 10, fastn: int = 2, slown: int = 30, *, item: str = None)
#         Kaufman Adaptive Moving Average
#
#     KELTNER(prices, period: int = 20, nbatr: float = 2.0)
#         Keltner Channel
#
#     LATR(prices, period: int = 14)
#         Average True Range (logarithmic)
#
#     LOG(series, *, item: str = None)
#         Logarithm
#
#     MA(series, period: int, *, ma_type: int = 0, item: str = None)
#         Generic Moving Average
#
#         Args:
#             series : data series, required
#             period (int) : time period, default 20
#             ma_type (int) : type of moving average, default 0 (SMA)
#
#     MACD(series, n1: int = 12, n2: int = 26, n3: int = 9, *, item: str = None)
#         Moving Average Convergenge Divergence
#
#     MAD(series, period: int, *, item: str = None)
#         Mean Absolute Deviation
#
#     MAX(series, period: int, *, item: str = None)
#         Rolling Maximum
#
#     MFI(prices, period: int = 14)
#         Money Flow Index
#
#     MIDPRICE(prices)
#         Mid Price
#
#     MIN(series, period: int, *, item: str = None)
#         Rolling Minimum
#
#     MINUSDI(prices, period: int = 14)
#         Minus Directional Index
#
#     NATR(prices, period: int = 14)
#         Average True Range (normalized)
#
#     PLUSDI(prices, period: int = 14)
#         Plus Directional Index
#
#     PPO(series, n1: int = 12, n2: int = 26, n3: int = 9, *, item: str = None)
#         Price Percentage Oscillator
#
#     PSAR(prices, afs: float = 0.02, maxaf: float = 0.2)
#         Parabolic Stop and Reverse
#
#     ROC(series, period: int = 1, *, item: str = None)
#         Rate of Change
#
#     RSI(series, period: int = 14, *, item: str = None)
#         Relative Strength Index
#
#     SLOPE(series, period: int = 20, *, option: int = 0, offset: int = 0, item: str = None)
#         Slope (time linear regression)
#
#     SMA(series, period: int, *, item: str = None)
#         Simple Moving Average
#
#     STDEV(series, period: int = 20, *, item: str = None)
#         Standard Deviation
#
#     STOCH(prices, period: int = 14, fastn: int = 3, slown: int = 3)
#         Stochastik Oscillator
#
#     STREAK(series, *, item: str = None)
#         Consecutive streak of ups/downs
#
#     SUM(series, period: int, *, item: str = None)
#         Rolling Sum
#
#     TEMA(series, period: int = 20, *, item: str = None)
#         Triple Exponential Moving Average
#
#     TRANGE(prices, *, log_prices: bool = False, percent: bool = False)
#         True Range
#
#     TYPPRICE(prices)
#         Typical Price
#
#     WCLPRICE(prices)
#         Weighted Close Price
#
#     WMA(series, period: int, *, item: str = None)
#         Weighted Moving Average
#
# DATA
#     __all__ = ['ADX', 'ATR', 'AVGPRICE', 'BBANDS', 'BOP', 'CCI', 'CMF', 'C...
#
# FILE
#     c:\users\frederic\onedrive\python\mintalib\src\mintalib\functions.py

# %%
help(indicators)
# Out:
# Help on module mintalib.indicators in mintalib:
#
# NAME
#     mintalib.indicators - Mintalib indicators library
#
# CLASSES
#     mintalib.model.Indicator(abc.ABC, mintalib.model.ReprMixin)
#         mintalib.core.ADX
#         mintalib.core.ATR
#         mintalib.core.AVGPRICE
#         mintalib.core.BBANDS
#         mintalib.core.BOP
#         mintalib.core.CCI
#         mintalib.core.CMF
#         mintalib.core.CURVE
#         mintalib.core.DEMA
#         mintalib.core.DIFF
#         mintalib.core.EMA
#         mintalib.core.EVAL
#         mintalib.core.EXP
#         mintalib.core.KAMA
#         mintalib.core.KELTNER
#         mintalib.core.LATR
#         mintalib.core.LOG
#         mintalib.core.MACD
#         mintalib.core.MAD
#         mintalib.core.MAX
#         mintalib.core.MFI
#         mintalib.core.MIDPRICE
#         mintalib.core.MIN
#         mintalib.core.MINUSDI
#         mintalib.core.NATR
#         mintalib.core.PLUSDI
#         mintalib.core.PPO
#         mintalib.core.PRICE
#         mintalib.core.PSAR
#         mintalib.core.RMA
#         mintalib.core.ROC
#         mintalib.core.RSI
#         mintalib.core.SLOPE
#         mintalib.core.SMA
#         mintalib.core.STDEV
#         mintalib.core.STOCH
#         mintalib.core.SUM
#         mintalib.core.TEMA
#         mintalib.core.TRANGE
#         mintalib.core.TYPPRICE
#         mintalib.core.VOLUME
#         mintalib.core.WCLPRICE
#         mintalib.core.WMA
#
#     class ADX(mintalib.model.Indicator)
#      |  ADX(period: 'int' = 14)
#      |
#      |  Average Directional Index
#      |
#      |  Method resolution order:
#      |      ADX
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 14)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class ATR(mintalib.model.Indicator)
#      |  ATR(period: 'int' = 14)
#      |
#      |  Average True Range
#      |
#      |  Method resolution order:
#      |      ATR
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 14)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class AVGPRICE(mintalib.model.Indicator)
#      |  Average Price Indicator
#      |
#      |  Method resolution order:
#      |      AVGPRICE
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class BBANDS(mintalib.model.Indicator)
#      |  BBANDS(period: 'int' = 20, nbdev: 'float' = 2.0)
#      |
#      |  Bollinger Bands
#      |
#      |  Method resolution order:
#      |      BBANDS
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 20, nbdev: 'float' = 2.0)
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class BOP(mintalib.model.Indicator)
#      |  BOP(period: 'int' = 20)
#      |
#      |  Balance of Power
#      |
#      |  Method resolution order:
#      |      BOP
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 20)
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class CCI(mintalib.model.Indicator)
#      |  CCI(period: 'int' = 20)
#      |
#      |  Commodity Channel Index
#      |
#      |  Method resolution order:
#      |      CCI
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 20)
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class CMF(mintalib.model.Indicator)
#      |  CMF(period: 'int' = 20)
#      |
#      |  Chaikin Money Flow
#      |
#      |  Method resolution order:
#      |      CMF
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 20)
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class CURVE(mintalib.model.Indicator)
#      |  CURVE(period: 'int' = 20, *, item=None)
#      |
#      |  Curve (time curvilinear regression)
#      |
#      |  Method resolution order:
#      |      CURVE
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 20, *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  ERROR = <class 'mintalib.core.CURVE.ERROR'>
#      |      Curve Root Mean Square Error
#      |
#      |  RVALUE = <class 'mintalib.core.CURVE.RVALUE'>
#      |      Curve R-Value
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class DEMA(mintalib.model.Indicator)
#      |  DEMA(period: 'int', *, item=None)
#      |
#      |  Double Exponential Moving Average
#      |
#      |  Args:
#      |      period (int) : time period, default 20
#      |
#      |  Method resolution order:
#      |      DEMA
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  same_scale = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class DIFF(mintalib.model.Indicator)
#      |  DIFF(period: 'int' = 1, *, item=None)
#      |
#      |  Difference
#      |
#      |  Method resolution order:
#      |      DIFF
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 1, *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class EMA(mintalib.model.Indicator)
#      |  EMA(period: 'int', *, item=None)
#      |
#      |  Exponential Moving Average
#      |
#      |  Args:
#      |      period (int) : time period, required
#      |      adjust (bool) : whether to adjust weights, default False
#      |          when true update ratio increases gradually (see formula)
#      |
#      |  Formula:
#      |      EMA is calculated as a recursive formula
#      |      The standard formula is ema += alpha * (value - ema)
#      |          with alpha = 2.0 / (period + 1.0)
#      |      The adjusted formula is ema = num/div
#      |          where num = value + rho * num, div = 1.0 + rho * div
#      |          with rho = 1.0 - alpha
#      |
#      |  Method resolution order:
#      |      EMA
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  same_scale = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class EVAL(mintalib.model.Indicator)
#      |  EVAL(expr)
#      |
#      |  Expression Eval (pandas only)
#      |
#      |  Args:
#      |      expr (str) : expression to evaluate on the dataframe, required
#      |
#      |  Method resolution order:
#      |      EVAL
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, expr)
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class EXP(mintalib.model.Indicator)
#      |  EXP(period: 'int', *, item=None)
#      |
#      |  Exponential
#      |
#      |  Method resolution order:
#      |      EXP
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  same_scale = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class KAMA(mintalib.model.Indicator)
#      |  KAMA(period: 'int' = 10, fastn: 'int' = 2, slown: 'int' = 30, *, item=None)
#      |
#      |  Kaufman Adaptative Moving Average
#      |
#      |  Method resolution order:
#      |      KAMA
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 10, fastn: 'int' = 2, slown: 'int' = 30, *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  same_scale = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class KELTNER(mintalib.model.Indicator)
#      |  KELTNER(period: 'int' = 20, nbatr: 'float' = 2.0)
#      |
#      |  Keltner Channel
#      |
#      |  Method resolution order:
#      |      KELTNER
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 20, nbatr: 'float' = 2.0)
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class LATR(mintalib.model.Indicator)
#      |  LATR(period: 'int' = 14)
#      |
#      |  Average True Range (log prices)
#      |
#      |  Method resolution order:
#      |      LATR
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 14)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class LOG(mintalib.model.Indicator)
#      |  LOG(period: 'int', *, item=None)
#      |
#      |  Logarithm
#      |
#      |  Method resolution order:
#      |      LOG
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  same_scale = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class MACD(mintalib.model.Indicator)
#      |  MACD(n1: 'int' = 12, n2: 'int' = 26, n3: 'int' = 9, *, item=None)
#      |
#      |  Moving Average Convergence Divergence
#      |
#      |  Method resolution order:
#      |      MACD
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, n1: 'int' = 12, n2: 'int' = 26, n3: 'int' = 9, *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class MAD(mintalib.model.Indicator)
#      |  MAD(period: 'int', *, item=None)
#      |
#      |  Mean Absolue Deviation
#      |
#      |  Method resolution order:
#      |      MAD
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class MAX(mintalib.model.Indicator)
#      |  MAX(period: 'int', *, item=None)
#      |
#      |  Rolling Maximum
#      |
#      |  Method resolution order:
#      |      MAX
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class MFI(mintalib.model.Indicator)
#      |  MFI(period: 'int' = 14)
#      |
#      |  Money Flow Index
#      |
#      |  Method resolution order:
#      |      MFI
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 14)
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class MIDPRICE(mintalib.model.Indicator)
#      |  Mid Price Indicator
#      |
#      |  Method resolution order:
#      |      MIDPRICE
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class MIN(mintalib.model.Indicator)
#      |  MIN(period: 'int', *, item=None)
#      |
#      |  Rolling Minimum
#      |
#      |  Method resolution order:
#      |      MIN
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class MINUSDI(mintalib.model.Indicator)
#      |  MINUSDI(period: 'int' = 14)
#      |
#      |  Minus Directional Index
#      |
#      |  Method resolution order:
#      |      MINUSDI
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 14)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class NATR(mintalib.model.Indicator)
#      |  NATR(period: 'int' = 14)
#      |
#      |  Average True Range (normalized)
#      |
#      |  Method resolution order:
#      |      NATR
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 14)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class PLUSDI(mintalib.model.Indicator)
#      |  PLUSDI(period: 'int' = 14)
#      |
#      |  Plus Directional Index
#      |
#      |  Method resolution order:
#      |      PLUSDI
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 14)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
# ...
#      |      Return repr(self).
#
#     class STDEV(mintalib.model.Indicator)
#      |  STDEV(period: 'int' = 20, *, item=None)
#      |
#      |  Standard Deviation
#      |
#      |  Method resolution order:
#      |      STDEV
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 20, *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class STOCH(mintalib.model.Indicator)
#      |  STOCH(period: 'int' = 14, fastn: 'int' = 3, slown: 'int' = 3, *, item=None)
#      |
#      |  Stockchastic Oscillator
#      |
#      |  Method resolution order:
#      |      STOCH
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 14, fastn: 'int' = 3, slown: 'int' = 3, *, item=None)
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class SUM(mintalib.model.Indicator)
#      |  SUM(period: 'int', *, item=None)
#      |
#      |  Rolling Sum
#      |
#      |  Method resolution order:
#      |      SUM
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  same_scale = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class TEMA(mintalib.model.Indicator)
#      |  TEMA(period: 'int' = 20, *, item=None)
#      |
#      |  Triple Exponential Moving Average
#      |
#      |  Args:
#      |      period (int) : time period. default 20
#      |
#      |  Method resolution order:
#      |      TEMA
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int' = 20, *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  same_scale = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class TRANGE(mintalib.model.Indicator)
#      |  True Range
#      |
#      |  Method resolution order:
#      |      TRANGE
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class TYPPRICE(mintalib.model.Indicator)
#      |  Typical Price Indicator
#      |
#      |  Method resolution order:
#      |      TYPPRICE
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class VOLUME(mintalib.model.Indicator)
#      |  Volume Indicator
#      |
#      |  Method resolution order:
#      |      VOLUME
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  item = 'volume'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class WCLPRICE(mintalib.model.Indicator)
#      |  Weighted Close Price Indicator
#      |
#      |  Method resolution order:
#      |      WCLPRICE
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  calc(self, prices)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  same_scale = False
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
#     class WMA(mintalib.model.Indicator)
#      |  WMA(period: 'int', *, item=None)
#      |
#      |  Weighted Moving Average
#      |
#      |  Method resolution order:
#      |      WMA
#      |      mintalib.model.Indicator
#      |      abc.ABC
#      |      mintalib.model.ReprMixin
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, period: 'int', *, item=None)
#      |
#      |  calc(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  same_scale = True
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.Indicator:
#      |
#      |  __call__(self, data)
#      |      Call self as a function.
#      |
#      |  __matmul__(self, other)
#      |
#      |  clone(self, **kwargs)
#      |
#      |  get_series(self, data)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from mintalib.model.Indicator:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes inherited from mintalib.model.Indicator:
#      |
#      |  default_item = 'close'
#      |
#      |  item = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from mintalib.model.ReprMixin:
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#
# DATA
#     __all__ = ['ADX', 'ATR', 'AVGPRICE', 'BBANDS', 'BOP', 'CCI', 'CMF', 'C...
#
# FILE
#     c:\users\frederic\onedrive\python\mintalib\src\mintalib\indicators.py
