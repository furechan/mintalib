# %% [markdown]
# # Bollinger Bands Function

# %%
import matplotlib as mpl

from mintalib.core import BBANDS
from mintalib.utils import random_prices

mpl.rc('figure', figsize=(12, 9))

# %%
prices = random_prices(260)
prices = prices.join(BBANDS(prices))
prices.tail()
# Out:
#               open    high     low   close  volume   upperband  middleband  \
# date
# 2023-09-18  129.67  130.75  129.48  129.73  134273  135.942299  131.506333
# 2023-09-19  128.79  130.48  128.79  130.13  105853  135.253095  131.210000
# 2023-09-20  131.45  131.91  130.73  130.73  149112  134.732241  131.028833
# 2023-09-21  130.60  130.60  128.78  129.30   94157  134.430735  130.838333
# 2023-09-22  129.03  130.62  129.03  130.62  142113  133.985921  130.652333
#
#              lowerband
# date
# 2023-09-18  127.070367
# 2023-09-19  127.166905
# 2023-09-20  127.325426
# 2023-09-21  127.245932
# 2023-09-22  127.318746

# %%
prices.plot(
    y=['close', 'upperband', 'middleband', 'lowerband'],
    style=['b', 'y--', 'k--', 'y--']
);
