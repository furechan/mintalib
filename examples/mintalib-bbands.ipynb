# %% [markdown]
# # Bollinger Bands Function

# %%
import matplotlib as mpl

from mintalib.utils import random_prices

from mintalib.funcs import BBANDS

mpl.rc('figure', figsize=(12, 9), facecolor='w')

# %%
prices = random_prices(260)
prices = prices.join(BBANDS(prices))
prices.tail()
# Out:
#               open    high     low   close  volume   upperband  middleband  \
# date
# 2023-09-11  134.82  134.82  133.11  133.11  151729  137.374017  133.693333
# 2023-09-12  132.96  133.72  132.45  133.72  136792  137.354692  133.765333
# 2023-09-13  132.41  132.41  131.56  131.67  176966  137.155128  133.853500
# 2023-09-14  131.65  132.66  131.65  132.66  153036  137.035544  133.920500
# 2023-09-15  132.50  133.20  131.50  131.50  116809  137.052728  133.905833
#
#              lowerband
# date
# 2023-09-11  130.012650
# 2023-09-12  130.175975
# 2023-09-13  130.551872
# 2023-09-14  130.805456
# 2023-09-15  130.758939

# %%
prices.plot(
    y=['close', 'upperband', 'middleband', 'lowerband'],
    style=['b', 'y--', 'k--', 'y--']
);
