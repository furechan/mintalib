# %% [markdown]
# # Keltner Channels Function

# %%
import matplotlib as mpl

from mintalib.functions import KELTNER
from mintalib.utils import random_prices

mpl.rc('figure', figsize=(12, 9))

# %%
prices = random_prices(260)
prices = prices.join(KELTNER(prices))
prices.tail()
# Out:
#              open   high    low  close  volume  upperband  middleband  \
# date
# 2023-10-23  89.31  89.39  88.69  88.69  131713  96.383597   93.134037
# 2023-10-24  88.06  88.81  87.54  87.54  128955  95.820193   92.641589
# 2023-10-25  87.69  87.78  86.97  87.78  127583  95.175610   92.152866
# 2023-10-26  87.30  87.92  86.93  87.92  122401  94.636777   91.718308
# 2023-10-27  88.12  88.12  87.75  87.82  134222  94.054964   91.354342
#
#             lowerband
# date
# 2023-10-23  89.884477
# 2023-10-24  89.462985
# 2023-10-25  89.130123
# 2023-10-26  88.799839
# 2023-10-27  88.653720

# %%
prices.plot(y=['close', 'upperband', 'middleband', 'lowerband'], style=['b', 'y--', 'k--', 'y--']);
