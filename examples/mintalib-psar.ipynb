# %%
import matplotlib as mpl

from mintalib.utils import sample_prices

from mintalib.functions import PSAR


mpl.rc('figure', figsize=(12, 9), facecolor='w')

# %%
prices = sample_prices(260).assign(psar = PSAR)
prices.tail()
# Out:
#              open   high    low  close  volume       psar
# date
# 2022-09-02  87.72  87.97  87.41  87.41  105171  89.290883
# 2022-09-05  87.49  87.49  86.81  86.97  130949  88.882777
# 2022-09-06  85.86  86.07  85.07  85.07  147573  88.523644
# 2022-09-07  85.16  85.16  83.91  83.91  141778  88.207607
# 2022-09-08  84.37  84.37  82.64  82.64  117127  87.768342

# %%
prices.plot(y=['close', 'psar'], style=['b', 'g.']);
