# %%
import matplotlib as mpl

from mintalib.core import PSAR
from mintalib.utils import random_prices

mpl.rc('figure', figsize=(12, 9))

# %%
prices = random_prices(260).assign(psar = PSAR)
prices.tail()
# Out:
#              open   high    low  close  volume       psar
# date
# 2023-09-18  87.34  88.56  87.34  88.35  122942  85.185800
# 2023-09-19  87.79  87.79  87.07  87.08  108035  85.230684
# 2023-09-20  86.93  87.77  86.93  87.77  114103  85.363857
# 2023-09-21  87.73  87.73  86.93  87.45  105511  85.491702
# 2023-09-22  88.11  88.62  87.98  88.62  148544  85.614434

# %%
prices.plot(y=['close', 'psar'], style=['b', 'g.']);
