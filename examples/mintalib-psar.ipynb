# %%
import matplotlib as mpl

from mintalib.utils import sample_prices

import mintalib.functions as ta


mpl.rc('figure', figsize=(12, 9), facecolor='w')

# %%
prices = sample_prices(260).assign(psar = ta.psar)
prices.tail()
# Out:
#              open   high    low  close  volume       psar
# date
# 2022-08-11  79.42  79.45  78.33  79.45  160174  77.946739
# 2022-08-12  79.23  79.58  78.89  79.58   97732  78.071270
# 2022-08-15  79.37  80.38  79.37  80.38  167592  78.190819
# 2022-08-16  80.57  80.57  79.60  80.39  126651  78.305586
# 2022-08-17  80.20  80.20  79.34  79.91   97215  78.415763

# %%
prices.plot(y=['close', 'psar'], style=['b', 'g.']);
