# %%
import matplotlib as mpl

from mintalib.utils import random_prices

from mintalib.funcs import PSAR


mpl.rc('figure', figsize=(12, 9), facecolor='w')

# %%
prices = random_prices(260).assign(psar = PSAR)
prices.tail()
# Out:
#               open    high     low   close  volume        psar
# date
# 2023-09-13  119.19  120.15  118.80  120.15  191809  114.721400
# 2023-09-14  120.61  120.90  119.62  119.62  133684  114.820772
# 2023-09-15  118.87  118.87  117.11  118.82  164208  115.033941
# 2023-09-18  118.21  119.27  118.07  118.07  116593  115.385905
# 2023-09-19  118.81  120.55  118.81  120.55  143094  115.716750

# %%
prices.plot(y=['close', 'psar'], style=['b', 'g.']);
