# %%
import  numpy as np
import polars as pl
from polars import col

import yfinance as yf

from mintalib.indicators import SMA, ATR, MACD

# %%
prices = yf.Ticker('AAPL').history('5y')
prices = prices.rename(columns=str.lower).rename_axis(index=str.lower)
prices = pl.from_pandas(prices, include_index=True)
prices


# Links
# https://docs.pola.rs/user-guide/expressions/user-defined-python-functions/#combining-multiple-column-values
# Out:
# shape: (1_258, 8)
# ┌─────────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┬────────┐
# │ date        ┆ open       ┆ high       ┆ low        ┆ close      ┆ volume    ┆ dividends ┆ stock  │
# │ ---         ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       ┆ splits │
# │ datetime[ns ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ i64       ┆ f64       ┆ ---    │
# │ , America/N ┆            ┆            ┆            ┆            ┆           ┆           ┆ f64    │
# │ ew_York]    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# ╞═════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪════════╡
# │ 2020-01-09  ┆ 74.46595   ┆ 75.239113  ┆ 74.21389   ┆ 75.045219  ┆ 170108400 ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ 2020-01-10  ┆ 75.280311  ┆ 75.78202   ┆ 74.710739  ┆ 75.214867  ┆ 140644800 ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ 2020-01-13  ┆ 75.532386  ┆ 76.848457  ┆ 75.41362   ┆ 76.821793  ┆ 121532000 ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ 2020-01-14  ┆ 76.758774  ┆ 76.969635  ┆ 75.660835  ┆ 75.784439  ┆ 161954400 ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ 2020-01-15  ┆ 75.583282  ┆ 76.467934  ┆ 75.025826  ┆ 75.459671  ┆ 121923600 ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ …           ┆ …          ┆ …          ┆ …          ┆ …          ┆ …         ┆ …         ┆ …      │
# │ 2025-01-02  ┆ 248.929993 ┆ 249.100006 ┆ 241.820007 ┆ 243.850006 ┆ 55740700  ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ 2025-01-03  ┆ 243.360001 ┆ 244.179993 ┆ 241.889999 ┆ 243.360001 ┆ 40244100  ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ 2025-01-06  ┆ 244.309998 ┆ 247.330002 ┆ 243.199997 ┆ 245.0      ┆ 45045600  ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ 2025-01-07  ┆ 242.979996 ┆ 245.550003 ┆ 241.350006 ┆ 242.210007 ┆ 40856000  ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ 2025-01-08  ┆ 241.970001 ┆ 243.712296 ┆ 240.050003 ┆ 242.699997 ┆ 36473385  ┆ 0.0       ┆ 0.0    │
# │ 00:00:00    ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# │ EST         ┆            ┆            ┆            ┆            ┆           ┆           ┆        │
# └─────────────┴────────────┴────────────┴────────────┴────────────┴───────────┴───────────┴────────┘

# %%
pstruct = prices.to_struct("prices")
pstruct
# Out:
# shape: (1_258,)
# Series: 'prices' [struct[8]]
# [
# 	{2020-01-09 00:00:00 EST,74.46595,75.239113,74.21389,75.045219,170108400,0.0,0.0}
# 	{2020-01-10 00:00:00 EST,75.280311,75.78202,74.710739,75.214867,140644800,0.0,0.0}
# 	{2020-01-13 00:00:00 EST,75.532386,76.848457,75.41362,76.821793,121532000,0.0,0.0}
# 	{2020-01-14 00:00:00 EST,76.758774,76.969635,75.660835,75.784439,161954400,0.0,0.0}
# 	{2020-01-15 00:00:00 EST,75.583282,76.467934,75.025826,75.459671,121923600,0.0,0.0}
# 	…
# 	{2025-01-02 00:00:00 EST,248.929993,249.100006,241.820007,243.850006,55740700,0.0,0.0}
# 	{2025-01-03 00:00:00 EST,243.360001,244.179993,241.889999,243.360001,40244100,0.0,0.0}
# 	{2025-01-06 00:00:00 EST,244.309998,247.330002,243.199997,245.0,45045600,0.0,0.0}
# 	{2025-01-07 00:00:00 EST,242.979996,245.550003,241.350006,242.210007,40856000,0.0,0.0}
# 	{2025-01-08 00:00:00 EST,241.970001,243.712296,240.050003,242.699997,36473385,0.0,0.0}
# ]

# %%
result = prices.with_columns(
    sma20 = SMA(20) @ col('close'),
    sma50 = SMA(50) @ col('close'),
    atr = ATR(14) @ pl.all()
)

result
# Out:
# shape: (1_258, 11)
# ┌────────────┬────────────┬────────────┬───────────┬───┬────────┬───────────┬───────────┬──────────┐
# │ date       ┆ open       ┆ high       ┆ low       ┆ … ┆ stock  ┆ sma20     ┆ sma50     ┆ atr      │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ splits ┆ ---       ┆ ---       ┆ ---      │
# │ datetime[n ┆ f64        ┆ f64        ┆ f64       ┆   ┆ ---    ┆ f64       ┆ f64       ┆ f64      │
# │ s, America ┆            ┆            ┆           ┆   ┆ f64    ┆           ┆           ┆          │
# │ /New_York] ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪════════╪═══════════╪═══════════╪══════════╡
# │ 2020-01-09 ┆ 74.46595   ┆ 75.239113  ┆ 74.21389  ┆ … ┆ 0.0    ┆ NaN       ┆ NaN       ┆ NaN      │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ 2020-01-10 ┆ 75.280311  ┆ 75.78202   ┆ 74.710739 ┆ … ┆ 0.0    ┆ NaN       ┆ NaN       ┆ NaN      │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ 2020-01-13 ┆ 75.532386  ┆ 76.848457  ┆ 75.41362  ┆ … ┆ 0.0    ┆ NaN       ┆ NaN       ┆ NaN      │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ 2020-01-14 ┆ 76.758774  ┆ 76.969635  ┆ 75.660835 ┆ … ┆ 0.0    ┆ NaN       ┆ NaN       ┆ NaN      │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ 2020-01-15 ┆ 75.583282  ┆ 76.467934  ┆ 75.025826 ┆ … ┆ 0.0    ┆ NaN       ┆ NaN       ┆ NaN      │
# │ 00:00:00   ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆ …         ┆ … ┆ …      ┆ …         ┆ …         ┆ …        │
# │ 2025-01-02 ┆ 248.929993 ┆ 249.100006 ┆ 241.82000 ┆ … ┆ 0.0    ┆ 249.8695  ┆ 237.68511 ┆ 4.433684 │
# │ 00:00:00   ┆            ┆            ┆ 7         ┆   ┆        ┆           ┆ 4         ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ 2025-01-03 ┆ 243.360001 ┆ 244.179993 ┆ 241.88999 ┆ … ┆ 0.0    ┆ 249.887   ┆ 237.84029 ┆ 4.280563 │
# │ 00:00:00   ┆            ┆            ┆ 9         ┆   ┆        ┆           ┆ 8         ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ 2025-01-06 ┆ 244.309998 ┆ 247.330002 ┆ 243.19999 ┆ … ┆ 0.0    ┆ 249.98500 ┆ 238.13017 ┆ 4.269809 │
# │ 00:00:00   ┆            ┆            ┆ 7         ┆   ┆        ┆ 1         ┆           ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ 2025-01-07 ┆ 242.979996 ┆ 245.550003 ┆ 241.35000 ┆ … ┆ 0.0    ┆ 249.95350 ┆ 238.36803 ┆ 4.264822 │
# │ 00:00:00   ┆            ┆            ┆ 6         ┆   ┆        ┆ 1         ┆ 8         ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# │ 2025-01-08 ┆ 241.970001 ┆ 243.712296 ┆ 240.05000 ┆ … ┆ 0.0    ┆ 249.75100 ┆ 238.59892 ┆ 4.221785 │
# │ 00:00:00   ┆            ┆            ┆ 3         ┆   ┆        ┆ 1         ┆ 4         ┆          │
# │ EST        ┆            ┆            ┆           ┆   ┆        ┆           ┆           ┆          │
# └────────────┴────────────┴────────────┴───────────┴───┴────────┴───────────┴───────────┴──────────┘
