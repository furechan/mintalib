# %% [markdown]
# # Parabolic Stop and Reverse

# %%
import matplotlib as mpl

from mintalib.functions import SAR
from mintalib.utils import random_prices

mpl.rc('figure', figsize=(12, 9))

# %%
prices = random_prices(260).assign(sar = SAR)
prices.tail()
# Out:
#               open    high     low   close  volume         sar
# date
# 2023-10-23  116.01  116.01  114.81  115.36  139632  112.463600
# 2023-10-24  114.45  114.45  111.39  111.39  116512  116.560000
# 2023-10-25  111.57  112.77  111.57  112.00  121454  116.456600
# 2023-10-26  112.44  113.40  112.42  113.40   91269  116.355268
# 2023-10-27  113.02  114.22  112.82  113.63  135331  116.255963

# %%
prices.plot(y=['close', 'sar'], style=['b', 'g.']);
