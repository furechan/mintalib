# %% [markdown]
# # Keltner Channels Function

# %%
import matplotlib as mpl

from mintalib.core import KELTNER
from mintalib.utils import random_prices

mpl.rc('figure', figsize=(12, 9))

# %%
prices = random_prices(260)
prices = prices.join(KELTNER(prices))
prices.tail()
# Out:
#               open    high     low   close  volume   upperband  middleband  \
# date
# 2023-09-18   99.28  100.51   99.28  100.51  128549  100.145826   97.597572
# 2023-09-19  100.28  100.49   99.74   99.74  130176  100.272851   97.825422
# 2023-09-20   99.60  100.82   99.57  100.74  132569  100.521084   98.068398
# 2023-09-21  100.98  100.98   99.66   99.66   98839  100.733301   98.261884
# 2023-09-22  100.63  101.62  100.59  101.62  146458  101.165282   98.549006
#
#             lowerband
# date
# 2023-09-18  95.049318
# 2023-09-19  95.377993
# 2023-09-20  95.615712
# 2023-09-21  95.790466
# 2023-09-22  95.932730

# %%
prices.plot(y=['close', 'upperband', 'middleband', 'lowerband'], style=['b', 'y--', 'k--', 'y--']);
