# %% [markdown]
# # Keltner Channels Function

# %%
import matplotlib as mpl

from mintalib.utils import sample_prices

from mintalib.functions import KELTNER

mpl.rc('figure', figsize=(12, 9), facecolor='w')

# %%
prices = sample_prices(260)
prices = prices.join(KELTNER(prices))
prices.tail()
# Out:
#              open   high    low  close  volume  upperband  middleband  \
# date
# 2022-09-02  59.13  59.60  59.13  59.60  118632  62.665590   60.821582
# 2022-09-05  59.45  60.20  59.03  59.03  143127  62.581705   60.688098
# 2022-09-06  58.78  59.17  58.76  58.76  178875  62.303732   60.517486
# 2022-09-07  58.08  58.71  58.05  58.05  192884  62.053061   60.303439
# 2022-09-08  57.75  58.20  57.75  58.20  161620  61.753485   60.088826
#
#             lowerband
# date
# 2022-09-02  58.977575
# 2022-09-05  58.794492
# 2022-09-06  58.731240
# 2022-09-07  58.553818
# 2022-09-08  58.424167

# %%
prices.plot(y=['close', 'upperband', 'middleband', 'lowerband'], style=['b', 'y--', 'k--', 'y--']);
