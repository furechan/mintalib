# %%
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

from mintalib.core import calc_keltner
from mintalib.utils import sample_prices

mpl.rc('figure', figsize=(12, 9), facecolor='w')
pd.set_option('display.max_rows', None)

# %%
prices = sample_prices(260)
prices = prices.join(calc_keltner(prices))
prices
# Out:
#               open    high     low   close  volume   upperband  middleband  \
# date
# 2021-08-16  100.69  101.11   99.51  101.11  150762         NaN         NaN
# 2021-08-17  100.46  100.46   98.85   98.85  138807         NaN         NaN
# 2021-08-18   98.34   99.12   98.34   98.71  109951         NaN         NaN
# 2021-08-19   98.12   98.63   97.82   98.63  108068         NaN         NaN
# 2021-08-20   99.19   99.19   97.62   97.62  139241         NaN         NaN
# 2021-08-23   98.11   98.57   97.56   97.56  145991         NaN         NaN
# 2021-08-24   98.26   99.17   98.26   99.17   88134         NaN         NaN
# 2021-08-25   98.59   98.59   97.34   97.34  165996         NaN         NaN
# 2021-08-26   96.41   98.23   96.41   98.15  206156         NaN         NaN
# 2021-08-27   97.97   98.73   97.97   98.73  135387         NaN         NaN
# 2021-08-30   98.91   99.75   98.82   98.82  142177         NaN         NaN
# ...

# %%
prices.plot(y=['close', 'upperband', 'middleband', 'lowerband'], style=['b', 'y--', 'k--', 'y--']);
