# %% [markdown]
# # Keltner Channels Function

# %%
import matplotlib as mpl

from mintalib.utils import sample_prices

import mintalib.functions as ta

mpl.rc('figure', figsize=(12, 9), facecolor='w')

# %%
prices = sample_prices(260)
prices = prices.join(ta.keltner(prices))
prices.tail()
# Out:
#              open   high    low  close  volume  upperband  middleband  \
# date
# 2022-08-11  73.83  74.68  73.83  74.29  210473  75.680990   73.984392
# 2022-08-12  74.31  74.31  73.48  73.71  194432  75.662944   73.970006
# 2022-08-15  73.79  73.79  72.63  72.63   97984  75.634856   73.879211
# 2022-08-16  72.95  72.95  71.85  71.85  134138  75.520954   73.720874
# 2022-08-17  72.08  73.23  72.08  73.23  158694  75.533688   73.637616
#
#             lowerband
# date
# 2022-08-11  72.287794
# 2022-08-12  72.277067
# 2022-08-15  72.123567
# 2022-08-16  71.920794
# 2022-08-17  71.741544

# %%
prices.plot(y=['close', 'upperband', 'middleband', 'lowerband'], style=['b', 'y--', 'k--', 'y--']);
