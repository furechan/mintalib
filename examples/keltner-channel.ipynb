# %% [markdown]
# # Keltner Channel

# %%
import matplotlib as mpl

from mintalib.functions import KELTNER
from mintalib.samples import sample_prices

mpl.rc("figure", figsize=(12, 9))

# %%
prices = sample_prices()
prices = prices.join(KELTNER(prices))
prices.tail()
# Out:
#                   open        high         low       close    volume  \
# date
# 2024-09-12  222.500000  223.550003  219.820007  222.770004  37498200
# 2024-09-13  223.580002  224.039993  221.910004  222.500000  36766600
# 2024-09-16  216.539993  217.220001  213.919998  216.320007  59357400
# 2024-09-17  215.750000  216.899994  214.500000  216.789993  45519300
# 2024-09-18  217.550003  222.710007  217.539993  220.690002  59788400
#
#              upperband  middleband   lowerband
# date
# 2024-09-12  232.201462  222.646236  213.091011
# 2024-09-13  231.688168  222.662467  213.636767
# 2024-09-16  231.849935  222.010804  212.171673
# 2024-09-17  230.779595  221.444378  212.109161
# 2024-09-18  230.922357  221.336659  211.750962

# %%
prices.tail(250).plot(
    y=["close", "upperband", "middleband", "lowerband"],
    style=["b", "y--", "k--", "y--"],
);
