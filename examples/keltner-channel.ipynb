# %% [markdown]
# # Keltner Channel

# %%
import matplotlib as mpl

import mintalib.functions as ta

from mintalib.samples import sample_prices

mpl.rc("figure", figsize=(12, 9))

# %%
prices = sample_prices()
prices = prices.join(ta.keltner(prices))
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11056 entries, 1980-12-12 to 2024-10-21
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   open        11056 non-null  float64
#  1   high        11056 non-null  float64
#  2   low         11056 non-null  float64
#  3   close       11056 non-null  float64
#  4   volume      11056 non-null  int64
#  5   upperband   11037 non-null  float64
#  6   middleband  11037 non-null  float64
#  7   lowerband   11037 non-null  float64
# dtypes: float64(7), int64(1)
# memory usage: 777.4 KB

# %%
prices.tail(250).plot(
    y=["close", "middleband", "upperband", "lowerband"],
    style=["k", "b--", "b:", "b:"],
);
