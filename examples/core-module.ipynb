# %% [markdown]
# # Core module contains low levels functions

# %%
from mintalib import core
from mintalib.samples import sample_prices

# %%
help(core)
# Out:
# Help on module mintalib.core in mintalib:
#
# NAME
#     mintalib.core
#
# FUNCTIONS
#     calc_adx(prices, period=14, *, wrap: 'bool' = False)
#         Average Directional Index
#
#     calc_atr(prices, period=14, *, wrap: 'bool' = False)
#         Average True Range
#
#     calc_avgprice(prices, *, wrap: 'bool' = False)
#         Average Price
#
#     calc_bbands(prices, period=20, nbdev=2.0, *, wrap: 'bool' = False)
#         Bollinger Bands
#
#     calc_bop(prices, period=20, *, wrap: 'bool' = False)
#         Balance of Power
#
#     calc_cci(prices, period=20, *, wrap: 'bool' = False)
#         Commodity Channel Index
#
#     calc_cmf(prices, period=20, *, wrap: 'bool' = False)
#         Chaikin Money Flow
#
#     calc_dema(series, period, wrap: 'bool' = False)
#         Double Exponential Moving Average
#
#     calc_diff(series, period=1, *, wrap: 'bool' = False)
#         Difference
#
#     calc_ema(series, period, *, adjust=False, wrap: 'bool' = False)
#         Exponential Moving Average
#
#         Args:
#             series (series) : data series, required
#             period (int) : time period, required
#             adjust (bool) : whether to adjust weights, default False
#                 when true update ratio increases gradually (see formula)
#
#         Formula:
#             EMA is calculated as a recursive formula
#             The standard formula is ema += alpha * (value - ema)
#                 with alpha = 2.0 / (period + 1.0)
#             The adjusted formula is ema = num/div
#                 where num = value + rho * num, div = 1.0 + rho * div
#                 with rho = 1.0 - alpha
#
#     calc_eval(prices, expr: 'str')
#         Expression Eval (pandas only)
#
#         Args:
#             expr (str) : expression to evaluate on the prices dataframe
#
#     calc_exp(series, *, wrap: 'bool' = False)
#         Exponential
#
#     calc_kama(series, period=10, fastn=2, slown=30, *, wrap: 'bool' = False)
#         Kaufman Adaptive Moving Average (Kaufman)
#
#     calc_keltner(prices, period=20, nbatr=2.0, *, wrap: 'bool' = False)
#         Keltner Channel
#
#     calc_ker(series, period=10, *, wrap: 'bool' = False)
#         Kayfman Efficiency Ratio
#
#     calc_latr(prices, period=14, *, wrap: 'bool' = False)
#         Average True Range (logarithmic)
#
#     calc_log(series, *, wrap: 'bool' = False)
#         Logarithm
#
#     calc_ma(series, period=20, *, ma_type: 'str' = None, wrap: 'bool' = False)
#         Generic Moving Average
#
#         Args:
#             series : data series, required
#             period (int) : time period, required
#             ma_type (str) : type of moving average, default 'SMA'
#                 one of 'SMA', 'EMA', 'WMA', 'RMA', 'DEMA', 'TEMA'
#
#     calc_macd(series, n1=12, n2=26, n3=9, wrap: 'bool' = False)
#         Moving Average Convergenge Divergence
#
#     calc_mad(series, period=20, *, wrap: 'bool' = False)
#         Mean Absolute Deviation
#
#     calc_max(series, period, *, wrap: 'bool' = False)
#         Rolling Maximum
#
#     calc_mfi(prices, period=14, *, wrap: 'bool' = False)
#         Money Flow Index
#
#     calc_midprice(prices, *, wrap: 'bool' = False)
#         Mid Price
#
#     calc_min(series, period, *, wrap: 'bool' = False)
#         Rolling Minimum
#
#     calc_minusdi(prices, period=14, *, wrap: 'bool' = False)
#         Minus Directional Index
#
#     calc_natr(prices, period=14, *, wrap: 'bool' = False)
#         Average True Range (normalized)
#
#     calc_plusdi(prices, period=14, *, wrap: 'bool' = False)
#         Plus Directional Index
#
#     calc_ppo(series, n1=12, n2=26, n3=9, *, wrap: 'bool' = False)
#         Price Percentage Oscillator
#
#     calc_price(prices, item: 'str' = None, *, wrap: 'bool' = False)
#         Generic Price
#
#     calc_rma(series, period, *, wrap: 'bool' = False)
#         Rolling Moving Average (RSI Style)
#
#         Exponential moving average with alpha = 2 / period,
#         but strats as a simple moving average till period bars.
#
#         Args:
#             series (series) : data series. required
#             period (int) : time period. rerquired
#
#     calc_roc(series, period=1, *, wrap: 'bool' = False)
#         Rate of Change
#
#     calc_rsi(series, period=14, *, wrap: 'bool' = False)
#         Relative Strength Index
#
#     calc_sar(prices, afs=0.02, maxaf=0.2, *, wrap: 'bool' = False)
#         Parabolic Stop and Reverse
#
#     calc_slope(series, period=20, *, option=0, offset=0, wrap: 'bool' = False)
#         Slope (time linear regression)
#
#     calc_sma(series, period, *, wrap: 'bool' = False)
#         Simple Moving Average
#
#         Args:
#             period (int) : time period, required
#
#     calc_stdev(series, period=20, *, wrap: 'bool' = False)
#         Standard Deviation
#
#     calc_stoch(prices, period=14, fastn=3, slown=3, *, wrap: 'bool' = False)
#         Stochastic Oscillator
#
#     calc_sum(series, period, *, wrap: 'bool' = False)
#         Rolling Sum
#
#     calc_tema(series, period=20, *, wrap: 'bool' = False)
#         Triple Exponential Moving Average
#
#         Args:
#             period (int) : time period. default 20
#
#     calc_trange(prices, *, log_prices: 'bool' = False, percent: 'bool' = False, wrap: 'bool' = False)
#         True Range
#
#     calc_typprice(prices, *, wrap: 'bool' = False)
#         Typical Price
#
#     calc_wclprice(prices, *, wrap: 'bool' = False)
#         Weighted Close Price
#
#     calc_wma(series, period, *, wrap: 'bool' = False)
#         Weighted Moving Average
#
#     check_size(xs, *others)
#         check all series have the same size and return the size
#
#     crossover(series, level=0.0, *, wrap: 'bool' = False)
#         Cross Over
#
#     crossunder(series, level=0.0, *, wrap: 'bool' = False)
#         Cross Under
#
#     dataframe_like(data)
#         check if data is dataframe like
#
#     flag_above(series, level=0.0, *, na_value=nan, wrap: 'bool' = False)
#         Flag for value above level
#
#     flag_below(series, level=0.0, *, na_value=nan, wrap: 'bool' = False)
#         Flag for value below level
#
#     get_series(data, item: 'str' = None, *, default_item: 'str' = 'close')
#         get series from either series/prices data
#
#     invert_flag(series, *, na_value=nan, wrap: 'bool' = False)
#         Invert flag
#
#     streak_down(series, *, wrap: 'bool' = False)
#         Consecutive streak of downs
#
#     streak_up(series, *, wrap: 'bool' = False)
#         Consecutive streak of ups
#
#     updown_flag(series, up_level=0.0, down_level=0.0, *, up_flag=1.0, down_flag=0.0, start_flag=nan, wrap: 'bool' = False)
#         Flag for value crossing levels up & down
#
#     where_flag(flag, x, y, z=nan, *, wrap: 'bool' = False)
#         Value according to flag
#
#     wrap_function(source, same_scale: 'bool' = None)
#         update function with documentation from source
#
#     wrap_indicator(source)
#         update indicagtor with documentation from source
#
#     wrap_result(result, source)
#         wrap result to match source data form (pandas, polars)
#
# DATA
#     __all__ = ('check_size', 'dataframe_like', 'get_series', 'wrap_functio...
#     __test__ = {}
#
# FILE
#     /Users/frederic/Projects/mintalib/src/mintalib/core.cpython-39-darwin.so

# %%
core.calc_ema.__module__
# Out:
# 'mintalib.core'

# %%
print(dir(core))
# Out:
# ['ADX', 'ATR', 'AVGPRICE', 'BBANDS', 'BOP', 'CCI', 'CMF', 'CROSSOVER', 'CROSSUNDER', 'DEMA', 'DIFF', 'EMA', 'EVAL', 'EXP', 'FLAG_ABOVE', 'FLAG_BELOW', 'FORECAST', 'INVERT_FLAG', 'IntEnum', 'KAMA', 'KELTNER', 'KER', 'LATR', 'LOG', 'MA', 'MACD', 'MAD', 'MAX', 'MFI', 'MIDPRICE', 'MIN', 'MINUSDI', 'NATR', 'PLUSDI', 'PPO', 'PRICE', 'PRICE_FUNCTIONS', 'RMA', 'ROC', 'RSI', 'RVALUE', 'SAR', 'SLOPE', 'SMA', 'STDEV', 'STOCH', 'STREAK_DOWN', 'STREAK_UP', 'SUM', 'SlopeOption', 'TEMA', 'TRANGE', 'TYPPRICE', 'UPDOWN_FLAG', 'WCLPRICE', 'WMA', '__all__', '__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__pyx_unpickle_Enum', '__spec__', '__test__', 'bbands_result', 'calc_adx', 'calc_atr', 'calc_avgprice', 'calc_bbands', 'calc_bop', 'calc_cci', 'calc_cmf', 'calc_dema', 'calc_diff', 'calc_ema', 'calc_eval', 'calc_exp', 'calc_kama', 'calc_keltner', 'calc_ker', 'calc_latr', 'calc_log', 'calc_ma', 'calc_macd', 'calc_mad', 'calc_max', 'calc_mfi', 'calc_midprice', 'calc_min', 'calc_minusdi', 'calc_natr', 'calc_plusdi', 'calc_ppo', 'calc_price', 'calc_rma', 'calc_roc', 'calc_rsi', 'calc_sar', 'calc_slope', 'calc_sma', 'calc_stdev', 'calc_stoch', 'calc_sum', 'calc_tema', 'calc_trange', 'calc_typprice', 'calc_wclprice', 'calc_wma', 'check_size', 'crossover', 'crossunder', 'dataframe_like', 'flag_above', 'flag_below', 'get_series', 'invert_flag', 'keltner_result', 'macd_result', 'namedtuple', 'np', 'ppo_result', 'stoch_result', 'streak_down', 'streak_up', 'sys', 'updown_flag', 'where_flag', 'wrap_function', 'wrap_indicator', 'wrap_result']

# %%
prices = sample_prices()
prices.tail()
# Out:
#                   open        high         low       close    volume
# date
# 2024-09-12  222.500000  223.550003  219.820007  222.770004  37498200
# 2024-09-13  223.580002  224.039993  221.910004  222.500000  36766600
# 2024-09-16  216.539993  217.220001  213.919998  216.320007  59357400
# 2024-09-17  215.750000  216.899994  214.500000  216.789993  45519300
# 2024-09-18  217.550003  222.710007  217.539993  220.690002  59788400

# %%
res = core.calc_sma(prices.close, 50)
res
# Out:
# array([         nan,          nan,          nan, ..., 222.75946014,
#        222.54412781, 222.38961578])

# %%
res = core.calc_macd(prices.close)
res
# Out:
# macd_result(macd=array([            nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan,             nan,             nan,             nan,
#                    nan, -3.13390080e-01, -6.47015514e-01, -1.09008940e+00,
#        -1.35061635e+00, -1.55529568e+00, -1.77531173e+00, -1.88278514e+00,
#        -1.77960579e+00, -1.68965495e+00, -1.62625010e+00, -1.73194431e+00,
#        -1.84208143e+00, -1.86350418e+00, -1.92047636e+00, -1.97114715e+00,
#        -2.11282771e+00, -2.22448254e+00, -2.31453139e+00, -2.28292259e+00,
#        -2.23214164e+00, -2.18925467e+00, -2.19452266e+00, -2.19438193e+00,
#        -2.28174311e+00, -2.28350195e+00, -2.24928449e+00, -2.12026187e+00,
#        -2.11148048e+00, -2.15711922e+00, -2.23290889e+00, -2.22216965e+00,
#        -2.22752016e+00, -2.15607090e+00, -2.21911126e+00, -2.28150345e+00,
#        -2.42883062e+00, -2.45116580e+00, -2.43514732e+00, -2.51530210e+00,
#        -2.50316921e+00, -2.56245918e+00, -2.49515121e+00, -2.52247231e+00,
#        -2.60128545e+00, -2.65572554e+00, -2.55324156e+00, -2.47974851e+00,
#        -2.29578958e+00, -2.21005778e+00, -2.14721881e+00, -2.03442796e+00,
#        -1.91170660e+00, -1.95012483e+00, -1.87344253e+00, -1.75611660e+00,
#        -1.70480863e+00, -1.70341568e+00, -1.69487801e+00, -1.64972880e+00,
#        -1.45834718e+00, -1.39389324e+00, -1.28842199e+00, -1.20945253e+00,
#        -1.03727472e+00, -8.29132278e-01, -6.35868174e-01, -4.26149937e-01,
#        -2.48209438e-01, -2.40783584e-01, -2.84871207e-01, -4.81294602e-01,
#        -7.22238349e-01, -8.44547685e-01, -8.01518844e-01, -8.52006004e-01,
#        -9.32108412e-01, -9.70683136e-01, -1.03052734e+00, -1.12310583e+00,
#        -1.13178577e+00, -1.10414999e+00, -1.14729403e+00, -1.06990212e+00,
#        -1.05052210e+00, -9.89862290e-01, -9.89289935e-01, -1.01346498e+00,
#        -8.80457232e-01, -6.72084124e-01, -5.37067197e-01, -5.10520406e-01,
#        -4.51994910e-01, -5.30221432e-01, -5.56749658e-01, -6.70106535e-01,
#        -6.60342190e-01, -6.48357679e-01, -5.78929840e-01, -3.48820509e-01,
#        -2.38748293e-01, -2.35942445e-01, -1.81596639e-01, -1.38543980e-01,
#        -5.53711674e-02, -8.84936516e-02, -2.21925870e-01, -3.07983296e-01,
#        -5.12296284e-01, -7.54281716e-01, -8.81030625e-01, -9.81463182e-01,
#        -1.07369424e+00, -1.14488729e+00, -1.22989738e+00, -1.33992070e+00,
#        -1.42201965e+00, -1.56905421e+00, -1.65919179e+00, -1.71409511e+00,
#        -1.91227754e+00, -1.94683895e+00, -1.87275643e+00, -1.68488258e+00,
#        -1.44509672e+00, -1.35403832e+00, -1.25290666e+00, -1.02059089e+00,
#        -7.78285479e-01, -5.22139809e-01, -3.62571096e-01, -2.31027847e-01,
#        -1.28524983e-01,  1.35926262e-01,  3.04075515e-01,  4.96168798e-01,
#         7.77425144e-01,  9.36273562e-01,  1.03410325e+00,  1.12848146e+00,
#         1.25338198e+00,  1.27792361e+00,  1.25945426e+00,  1.23382209e+00,
#         1.16059094e+00,  1.13944869e+00,  1.14659423e+00,  1.21570719e+00,
#         1.31902125e+00,  1.28761179e+00,  1.33926977e+00,  1.30305572e+00,
#         1.30610105e+00,  1.05667958e+00,  9.36971247e-01,  8.90738553e-01,
#         7.88525034e-01,  6.32448629e-01,  3.90480522e-01,  2.89787782e-01,
#         1.92438339e-01, -1.36609490e-02, -1.31902147e-01, -6.74825483e-02,
#         7.07092461e-02,  1.38287327e-01,  1.94443518e-01,  1.04600722e-01,
#         4.41871263e-02,  1.13730522e-03, -5.48164069e-03,  3.16742466e-02,
#         4.36718877e-02,  7.57079667e-02,  1.82503186e-03,  6.93868654e-03,
#         4.95667417e-04,  3.21372260e-02,  3.91181211e-03, -6.53122223e-02,
#        -1.33959973e-01, -1.35163083e-01, -1.89608106e-01, -2.22924199e-01,
#        -2.19363598e-01, -1.67806276e-01, -5.92892152e-02, -5.65560280e-02,
#        -1.23969559e-01, -7.32654076e-02, -1.33217820e-01, -2.64027057e-01,
#        -3.89828857e-01, -5.88450451e-01, -7.81234316e-01, -9.07418435e-01,
#        -9.86367036e-01, -1.10398925e+00, -1.10139709e+00, -1.10994856e+00,
#        -1.07528150e+00, -1.07176421e+00, -9.63461334e-01, -8.75606242e-01,
#        -8.62208591e-01, -8.37897514e-01, -8.21267495e-01, -7.53409019e-01,
#        -7.81800139e-01, -8.58952155e-01, -9.25564678e-01, -9.82362926e-01,
#        -9.90140893e-01, -8.86831427e-01, -7.67066673e-01, -7.03580707e-01,
#        -5.84398474e-01, -5.04305290e-01, -4.04696039e-01, -2.76572597e-01,
#        -1.34748561e-01,  4.88998846e-02,  2.83964622e-01,  4.94411757e-01,
#         6.77589293e-01,  6.72186060e-01,  6.06047504e-01,  4.84303079e-01,
#         3.45907270e-01,  1.96042664e-01,  1.41008654e-01,  7.79363262e-02,
#         2.60370797e-02,  4.65030594e-02, -2.73370199e-02, -8.56751216e-02]), macdsignal=array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan, -1.39824816, -1.44384855,
#        -1.5014677 , -1.56959045, -1.62837319, -1.68679383, -1.74366449,
#        -1.81749714, -1.89889422, -1.98202165, -2.04220184, -2.0801898 ,
#        -2.10200277, -2.12050675, -2.13528179, -2.16457405, -2.18835963,
#        -2.2005446 , -2.18448806, -2.16988654, -2.16733308, -2.18044824,
#        -2.18879252, -2.19653805, -2.18844462, -2.19457795, -2.21196305,
#        -2.25533656, -2.29450241, -2.32263139, -2.36116553, -2.38956627,
#        -2.42414485, -2.43834612, -2.45517136, -2.48439418, -2.51866045,
#        -2.52557667, -2.51641104, -2.47228675, -2.41984095, -2.36531653,
#        -2.29913881, -2.22165237, -2.16734686, -2.108566  , -2.03807612,
#        -1.97142262, -1.91782123, -1.87323259, -1.82853183, -1.7544949 ,
#        -1.68237457, -1.60358405, -1.52475775, -1.42726114, -1.30763537,
#        -1.17328193, -1.02385553, -0.86872631, -0.74313777, -0.65148445,
#        -0.61744648, -0.63840486, -0.67963342, -0.70401051, -0.73360961,
#        -0.77330937, -0.81278412, -0.85633277, -0.90968738, -0.95410706,
#        -0.98411564, -1.01675132, -1.02738148, -1.0320096 , -1.02358014,
#        -1.0167221 , -1.01607068, -0.98894799, -0.92557522, -0.84787361,
#        -0.78040297, -0.71472136, -0.67782137, -0.65360703, -0.65690693,
#        -0.65759398, -0.65574672, -0.64038335, -0.58207078, -0.51340628,
#        -0.45791351, -0.40265014, -0.34982891, -0.29093736, -0.25044862,
#        -0.24474407, -0.25739191, -0.30837279, -0.39755457, -0.49424978,
#        -0.59169246, -0.68809282, -0.77945171, -0.86954085, -0.96361682,
#        -1.05529739, -1.15804875, -1.25827736, -1.34944091, -1.46200823,
#        -1.55897438, -1.62173079, -1.63436115, -1.59650826, -1.54801427,
#        -1.48899275, -1.39531238, -1.271907  , -1.12195356, -0.97007707,
#        -0.82226722, -0.68351878, -0.51962977, -0.35488871, -0.18467721,
#         0.00774326,  0.19344932,  0.36158011,  0.51496038,  0.6626447 ,
#         0.78570048,  0.88045124,  0.95112541,  0.99301851,  1.02230455,
#         1.04716249,  1.08087143,  1.12850139,  1.16032347,  1.19611273,
#         1.21750133,  1.23522127,  1.19951293,  1.1470046 ,  1.09575139,
#         1.03430612,  0.95393462,  0.8412438 ,  0.7309526 ,  0.62324975,
#         0.49586761,  0.37031366,  0.28275441,  0.24034538,  0.21993377,
#         0.21483572,  0.19278872,  0.1630684 ,  0.13068218,  0.10344942,
#         0.08909438,  0.08000988,  0.0791495 ,  0.06368461,  0.05233542,
#         0.04196747,  0.04000142,  0.0327835 ,  0.01316436, -0.01626051,
#        -0.04004102, -0.06995444, -0.10054839, -0.12431143, -0.1330104 ,
#        -0.11826616, -0.10592414, -0.10953322, -0.10227966, -0.10846729,
#        -0.13957924, -0.18962917, -0.26939342, -0.3717616 , -0.47889297,
#        -0.58038778, -0.68510808, -0.76836588, -0.83668242, -0.88440223,
#        -0.92187463, -0.93019197, -0.91927482, -0.90786158, -0.89386877,
#        -0.87934851, -0.85416061, -0.83968852, -0.84354125, -0.85994593,
#        -0.88442933, -0.90557164, -0.9018236 , -0.87487221, -0.84061391,
#        -0.78937083, -0.73235772, -0.66682538, -0.58877483, -0.49796957,
#        -0.38859568, -0.25408362, -0.10438454,  0.05201022,  0.17604539,
#         0.26204581,  0.30649727,  0.31437927,  0.29071195,  0.26077129,
#         0.2242043 ,  0.18457085,  0.15695729,  0.12009843,  0.07894372]), macdhist=array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan, -0.29140679, -0.18240156,
#        -0.23047661, -0.27249099, -0.23513098, -0.23368254, -0.22748266,
#        -0.29533058, -0.32558832, -0.33250974, -0.24072075, -0.15195184,
#        -0.08725189, -0.07401591, -0.05910015, -0.11716906, -0.09514232,
#        -0.04873989,  0.06422618,  0.05840606,  0.01021386, -0.05246065,
#        -0.03337712, -0.03098211,  0.03237372, -0.02453332, -0.0695404 ,
#        -0.17349406, -0.15666339, -0.11251593, -0.15413657, -0.11360294,
#        -0.13831433, -0.05680509, -0.06730095, -0.11689127, -0.13706509,
#        -0.02766489,  0.03666253,  0.17649717,  0.20978318,  0.21809771,
#         0.26471086,  0.30994577,  0.21722203,  0.23512346,  0.28195951,
#         0.26661399,  0.21440555,  0.17835458,  0.17880303,  0.29614772,
#         0.28848133,  0.31516206,  0.31530522,  0.38998642,  0.47850309,
#         0.53741376,  0.59770559,  0.62051687,  0.50235418,  0.36661325,
#         0.13615188, -0.08383349, -0.16491426, -0.09750834, -0.1183964 ,
#        -0.15879904, -0.15789902, -0.17419458, -0.21341845, -0.17767871,
#        -0.12003435, -0.13054271, -0.04252064, -0.0185125 ,  0.03371785,
#         0.02743217,  0.00260569,  0.10849076,  0.25349109,  0.31080641,
#         0.26988256,  0.26272645,  0.14759994,  0.09685737, -0.0131996 ,
#        -0.00274821,  0.00738904,  0.06145351,  0.23325027,  0.27465799,
#         0.22197107,  0.2210535 ,  0.21128493,  0.23556619,  0.16195497,
#         0.0228182 , -0.05059138, -0.2039235 , -0.35672714, -0.38678084,
#        -0.38977072, -0.38560142, -0.36543558, -0.36035654, -0.37630389,
#        -0.36672227, -0.41100546, -0.40091443, -0.3646542 , -0.4502693 ,
#        -0.38786458, -0.25102564, -0.05052144,  0.15141154,  0.19397595,
#         0.23608609,  0.37472149,  0.49362152,  0.59981375,  0.60750597,
#         0.59123938,  0.55499379,  0.65555603,  0.65896423,  0.68084601,
#         0.76968188,  0.74282424,  0.67252314,  0.61352108,  0.59073728,
#         0.49222313,  0.37900302,  0.28269668,  0.16757243,  0.11714414,
#         0.09943175,  0.13483576,  0.19051986,  0.12728832,  0.14315704,
#         0.08555439,  0.07087978, -0.14283336, -0.21003335, -0.20501284,
#        -0.24578108, -0.32148599, -0.45076328, -0.44116481, -0.43081141,
#        -0.50952856, -0.5022158 , -0.35023696, -0.16963614, -0.08164644,
#        -0.0203922 , -0.088188  , -0.11888128, -0.12954488, -0.10893106,
#        -0.05742014, -0.036338  , -0.00344153, -0.06185958, -0.04539674,
#        -0.0414718 , -0.0078642 , -0.02887169, -0.07847658, -0.11769946,
#        -0.09512206, -0.11965366, -0.12237581, -0.09505216, -0.03479587,
#         0.05897695,  0.04936811, -0.01443634,  0.02901425, -0.02475053,
#        -0.12444781, -0.20019969, -0.31905703, -0.40947271, -0.42852547,
#        -0.40597925, -0.41888117, -0.33303121, -0.27326615, -0.19087927,
#        -0.14988959, -0.03326936,  0.04366858,  0.04565299,  0.05597125,
#         0.05808102,  0.10075159,  0.05788838, -0.01541091, -0.06561875,
#        -0.0979336 , -0.08456925,  0.01499217,  0.10780554,  0.13703321,
#         0.20497235,  0.22805243,  0.26212934,  0.31220223,  0.36322101,
#         0.43749557,  0.53804824,  0.5987963 ,  0.62557907,  0.49614067,
#         0.34400169,  0.17780581,  0.031528  , -0.09466928, -0.11976263,
#        -0.14626797, -0.15853377, -0.11045423, -0.14743545, -0.16461884]))
